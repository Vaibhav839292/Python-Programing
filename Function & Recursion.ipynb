# %% [markdown]
# **Function**

# %%
def hello():
  print("hello world")

hello()

def add():
  x = 56
  y =23
  print(x+y)

add()
# Out:
# hello world
# 79

# %%
def add(x,y):
    print(x+y)
add(12,45)
# Out:
# 57

# %%
def rect (length,width):
    print("the area of the rectangle is ",length*width)
rect(5,6)
# Out:
# the area of the rectangle is  30

# %% [markdown]
# **Parameter**

# %%
def hello (*names):
    for name in names:
        print("hello, my name is",name)

hello("john","lisa","peter")
# Out:
# hello, my name is john
# hello, my name is lisa
# hello, my name is peter

# %% [markdown]
# **Return Statement**

# %%
def hello():
    return("hello world")
print(    hello())

def add (a,b):
    return(a+b)
print(add(12,4))
# Out:
# hello world
# 16

# %% [markdown]
# **Recursion**

# %%
def fact (n):
    if n == 1:
       return 1
    else:
       return(n*fact(n-1))
print(fact(5))
# Out:
# 120

# %% [markdown]
# **Lembda Function**

# %%
a = lambda b: b*5
print(a(4))

x = lambda a,b,c: (a+b)*c
print(x(2,3,4))
# Out:
# 20
# 20

# %% [markdown]
# **Local & Global Variable**

# %%
x = 24
print("first variable x", x)
def hello():
  global x
  x =25
  return(x)
print(hello())

print(x)
# Out:
# first variable x 24
# 25
# 25

# %% [markdown]
# **Problem Solving**

# %%
#find maximum of three number in python
#to create and print a list where the values are square of number b/w 1 to 30
#write a python function that takes a number as a parameter and check if thehnumber is prime or not.
#pyhton function to sum all number in a list
#to solve the fabonacci sequence by recursion

# %%
def maximum_num(val1,val2,val3):
    if val1>val2 and val1>val3:
      print(val1,"is the greatest number")
    elif val2>val1 and val2>val3:
      print(val2,"is the greatest number")
    else:
      print(val3,"is the greatest number")
maximum_num(10,20,30)
# Out:
# 30 is the greatest number

# %%
def create_list():
    l = []
    for i in range(1,31):
      l.append(i**2)
    return l
print(create_list())
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]

# %%
def check_prime(num):
    if num == 1:
      print("it is not a prime number")
    if num == 2:
       print("it is a prime number")
    if num>2:
     for i in range (2,num):
        if num%i == 0:
            print ("it is not a prime number")
            break
        else:
            print("it is a prime number")
            break
check_prime(11)
# Out:
# it is a prime number

# %%
def add(numbers):
   total = 0
   for i in numbers:
       total = total +i
   return total
print(add([1,2,3,4,5]))
# Out:
# 15

# %%
def add (numbers):
    if len(numbers) == 1:
       return numbers[0] # Return the base value
    else:
       return numbers[0] + add(numbers[1:]) # Return the sum for further calculation
print(add([1,2,3,4,5]))
# Out:
# 15

# %%
def fs(num):
   if num == 1:
      return(0)
   elif num ==2:
      return(1)
   else:
       return (fs(num-1) + fs(num-2))
print(fs(8))
# Out:
# 13
