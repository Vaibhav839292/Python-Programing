# %%
a = "apple","mango","banana"

print(type(a))
print(a)

b = "Ironman"

print(type(b))
# Out:
# <class 'tuple'>
# ('apple', 'mango', 'banana')
# <class 'str'>

# %%
#Slicing and Interation in Tuples

a=("OnePlus","Vivo","Redme","Sumsung","Nokia")

print(a[1:3])
print(a[:3])

print(a[2:])
print(a[1::2])
print(a[::-1])
print(a[2::-1])
# Out:
# ('Vivo', 'Redme')
# ('OnePlus', 'Vivo', 'Redme')
# ('Redme', 'Sumsung', 'Nokia')
# ('Vivo', 'Sumsung')
# ('Nokia', 'Sumsung', 'Redme', 'Vivo', 'OnePlus')
# ('Redme', 'Vivo', 'OnePlus')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3470886426.py in <cell line: 0>()
#      12
#      13
# ---> 14 print(*20)
#
# TypeError: print() argument after * must be an iterable, not int

# %%
#Conversion of Tuples And Tuple Function

a=("Opeplus","Nokia","Redmi")

print(a.count("Redmi"))

print(a.index("Nokia"))


print("before conversion",type(a))

a = list(a)
print("after conversion",type(a))
a.append("vivp")
print(a)
a = tuple(a)
print(type(a))
print(a)
# Out:
# 1
# 1
# before conversion <class 'tuple'>
# after conversion <class 'list'>
# ['Opeplus', 'Nokia', 'Redmi', 'vivp']
# <class 'tuple'>
# ('Opeplus', 'Nokia', 'Redmi', 'vivp')

# %%
#Problem Solving


#Convert the following dictionary into JSON format.

import json

student_data = {"name":"David","age":13,"marks":87}
print(type(student_data))
data = json.dumps(student_data)
print(data)
print(type(data))


#Access the value of age from the given data.


# The 'data' variable already holds the JSON string. json.loads expects a string, not a dict.
loaded_data = json.loads(data)
# Access dictionary elements using square brackets and call print as a function.
print(loaded_data["age"])

#pretty print following JSON data.
student_data = {"name":"David","age":13,"marks":87}
data = json.dumps(student_data,indent = 4, separators =(",","="))
print(data)

#sort the following JSON keys and write them into a file.
f = open("demo.json","w")
json.dump(student_data,f, indent = 4, sort_keys = True)
print("the data has been added to the file ")
# Out:
# <class 'dict'>
# {"name": "David", "age": 13, "marks": 87}
# <class 'str'>
# 13
# {
#     "name"="David",
#     "age"=13,
#     "marks"=87
# }
# the data has been added to the file
