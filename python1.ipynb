# %%
print("Hello World")
# Out:
# Hello World

# %%
print("i am good boy")
# Out:
# i am good boy

# %%
print("""Hello world
this is my first program
i am good boy""")
# Out:
# Hello world
# this is my first program
# i am good boy

# %%
print("hello world\n vaibhav\nmishra")
# Out:
# hello world
#  vaibhav
# mishra

# %%
#comment in python
"""multiline comment"""
# Out:
# 'multiline comment'

# %%
#Variable

a = "hello"
print(a)
# Out:
# hello

# %%
#variable in python
#case senstive,

# %%
#data types

# %%
#user- input

name = input("enter your name here")
print(name)
# Out:
# enter your name herevaibhav
# vaibhav

# %%
name = int(input("enter your age"))
print(name)
# Out:
# enter your age25
# 25

# %%
name = float(input("enter your age"))
print (name)
# Out:
# enter your age24
# 24.0

# %%
exp1 = eval (input("enter any equation here"))
print (exp1)
# Out:
# enter any equation here5
# 5

# %% [markdown]
# *type casting**

# %%
name = "jhon"
print(type(name))
# Out:
# <class 'str'>

# %%
age = 23
print(type(age))
# Out:
# <class 'int'>

# %%
a = 123
b = 1.23
print (type(a))
print (type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# **Problem solving**

# %%
#write a program to display a person's name , age and adress in three diffrent lines

name = "vibhav"
age = 23
address = "64 lakh street"

print (name)
print (age)
print(address)
# Out:
# vibhav
# 23
# 64 lakh street

# %%
 # write a program to swap two variable:
 #METHOD 1

x = 12
y = 13
temp = x
print (temp)
x = y
y = temp
print (y)
print ("value of x is",x)
print ("value of y is", y)
# Out:
# 12
# 12
# value of x is 13
# value of y is 12

# %%
#METHOD 2

a = 30
b = 40

a ,b = b,a
print (b)
print(a)
# Out:
# 30
# 40

# %%
#write a program to convert a float into integer

x = 12.4
print (type(x))

x = int(x)
print(type(x))
print (x)
# Out:
# <class 'float'>
# <class 'int'>
# 12

# %%
#write a program to take details from a student for id-card and then print it in diffrent lines:


name = input("enter of the student name")
grade = input("enter of the student grade")
section = input("enter of the student section")
rollno = input("enter of the student rollno")
email = input("enter of the student email")
print("Student Identity Card")
print("name :", name)
print("grade :", grade)
print("section", section)
print("rollno :", rollno)
print("email :", email)
# Out:
# enter of the student nameVaibhav
# enter of the student grade3
# enter of the student sectionf
# enter of the student rollno234
# enter of the student emailvaib@123
# Student Identity Card
# name : Vaibhav
# grade : 3
# section f
# rollno : 234
# email : vaib@123

# %%
#write a program to take an user input as integer then convert it to  float


a = int(input("ente rnumber here"))
print (a)
print (type(a))
a = float (a)
print ("after conversation", a)
print (type (a))
# Out:
# ente rnumber here12
# 12
# <class 'int'>
# after conversation 12.0
# <class 'float'>

# %% [markdown]
# **Operators and Operands**
